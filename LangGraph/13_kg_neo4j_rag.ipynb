# %% [markdown]
# # Knowledge Graphs and RAG with Neo4j and LangChain v1.x
#
# This notebook explores:
# - Why Knowledge Graphs matter for RAG systems
# - Neo4j fundamentals and Cypher query language
# - Building RAG systems with structured knowledge
# - Advanced patterns using LangChain v1.x agents

# %% [markdown]
# ## Part 1: Why Knowledge Graphs?
#
# ### The Core Difference
# Traditional RAG stores information as text chunks. Knowledge Graphs store information as **relationships between entities**.
#
# ### Key Components
# 1. **Nodes (Entities)**: Things that exist - people, places, concepts
# 2. **Edges (Relations)**: How things connect - FOUNDED, ACTED_IN, DIRECTED
# 3. **Properties (Attributes)**: Details about nodes/edges - {name: "Alice", age: 30}
#
# ### The Problem Knowledge Graphs Solve
#
# **Traditional RAG:** Query "Which companies founded by Stanford dropouts are now worth over $1 trillion?"
# - Embed question, find similar documents
# - Hope the right chunks are retrieved
# - LLM must infer relationships from disconnected text
#
# **Knowledge Graph RAG:** Same query
# - Direct Cypher query: `MATCH (person:Person)-[:ATTENDED]->(stanford:University {name: "Stanford"})`
# - Graph already knows the relationships
# - Query structured knowledge, not text fragments

# %% [markdown]
# ## Part 2: Environment Setup

# %%
import os
from dotenv import load_dotenv

load_dotenv()

# Load environment variables
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["NEO4J_URI"] = os.getenv("NEO4J_URI")
os.environ["NEO4J_USERNAME"] = os.getenv("NEO4J_USERNAME")
os.environ["NEO4J_PASSWORD"] = os.getenv("NEO4J_PASSWORD")

# %% [markdown]
# ## Part 3: Neo4j Fundamentals
#
# ### Cypher Query Language Basics
#
# **Node Syntax:** `(variable:Label {property: value})`
# - `()` defines a node
# - `:Label` categorizes the node type
# - `{properties}` stores node attributes
#
# **Relationship Syntax:** `-[:TYPE {property: value}]->`
# - `--` defines connection
# - `->` shows direction
# - `[:TYPE]` categorizes the relationship
#
# **Pattern Matching:** Describe what you're looking for
# ```cypher
# MATCH (person:Person)-[:ACTED_IN]->(movie:Movie)
# WHERE movie.title = "Casino"
# RETURN person.name
# ```

# %%
# Connect to Neo4j
from langchain_community.graphs import Neo4jGraph

graph = Neo4jGraph(
    url=os.getenv("NEO4J_URI"),
    username=os.getenv("NEO4J_USERNAME"),
    password=os.getenv("NEO4J_PASSWORD")
)

print("Connected to Neo4j successfully")
# Out:
# /var/folders/_v/fs86q2353gvdsjh19x_1fpdm0000gn/T/ipykernel_85498/1458828603.py:4: LangChainDeprecationWarning: The class `Neo4jGraph` was deprecated in LangChain 0.3.8 and will be removed in 1.0. An updated version of the class exists in the `langchain-neo4j package and should be used instead. To use it run `pip install -U `langchain-neo4j` and import as `from `langchain_neo4j import Neo4jGraph``.
#   graph = Neo4jGraph(
# Connected to Neo4j successfully

# %% [markdown]
# ## Part 4: Load Movie Dataset into Neo4j
#
# We'll load a movies dataset with actors, directors, and genres to demonstrate graph capabilities.

# %%
# Clear existing data (optional - use cautiously)
graph.query("MATCH (n) DETACH DELETE n")
print("Existing data cleared")
# Out:
# Existing data cleared

# %%
# Load movies dataset from CSV
# Creates Movie nodes with properties, Person nodes for actors/directors, Genre nodes
# Establishes ACTED_IN, DIRECTED, and IN_GENRE relationships

movie_query = """
LOAD CSV WITH HEADERS FROM
'https://raw.githubusercontent.com/tomasonjo/blog-datasets/main/movies/movies_small.csv' as row

MERGE(m:Movie{id:row.movieId})
SET m.released = date(row.released),
    m.title = row.title,
    m.imdbRating = toFloat(row.imdbRating)

FOREACH (director in split(row.director, '|') | 
    MERGE (p:Person {name:trim(director)})
    MERGE (p)-[:DIRECTED]->(m))

FOREACH (actor in split(row.actors, '|') | 
    MERGE (p:Person {name:trim(actor)})
    MERGE (p)-[:ACTED_IN]->(m))

FOREACH (genre in split(row.genres, '|') | 
    MERGE (g:Genre {name:trim(genre)})
    MERGE (m)-[:IN_GENRE]->(g))
"""

graph.query(movie_query)
print("Movie dataset loaded successfully")
# Out:
# Movie dataset loaded successfully

# %%
# Refresh schema to get current graph structure
graph.refresh_schema()
print("Graph Schema:")
print(graph.schema)
# Out:
# Graph Schema:
# Node properties:
# Movie {id: STRING, released: DATE, title: STRING, imdbRating: FLOAT}
# Person {name: STRING}
# Genre {name: STRING}
# Relationship properties:
#
# The relationships:
# (:Movie)-[:IN_GENRE]->(:Genre)
# (:Person)-[:DIRECTED]->(:Movie)
# (:Person)-[:ACTED_IN]->(:Movie)

# %% [markdown]
# ## Part 5: Basic Cypher Query Examples

# %%
# Example 1: Find all movies
result = graph.query("""
MATCH (m:Movie)
RETURN m.title, m.released, m.imdbRating
ORDER BY m.imdbRating DESC
LIMIT 5
""")

print("Top 5 rated movies:")
for movie in result:
    print(f"{movie['m.title']} ({movie['m.released']}) - Rating: {movie['m.imdbRating']}")
# Out:
# Top 5 rated movies:
# Shawshank Redemption, The (1994-10-14) - Rating: 9.3
# Pulp Fiction (1994-10-14) - Rating: 8.9
# Star Wars: Episode IV - A New Hope (1977-05-25) - Rating: 8.7
# Seven (a.k.a. Se7en) (1995-09-22) - Rating: 8.6
# Usual Suspects, The (1995-09-15) - Rating: 8.6

# %%
# Example 2: Find actors in a specific movie
result = graph.query("""
MATCH (p:Person)-[:ACTED_IN]->(m:Movie {title: 'Casino'})
RETURN p.name
""")

print("Actors in Casino:")
for actor in result:
    print(f"- {actor['p.name']}")
# Out:
# Actors in Casino:
# - Robert De Niro
# - Joe Pesci
# - Sharon Stone
# - James Woods

# %%
# Example 3: Find director and actors for a movie
result = graph.query("""
MATCH (d:Person)-[:DIRECTED]->(m:Movie {title: 'Casino'})
OPTIONAL MATCH (a:Person)-[:ACTED_IN]->(m)
RETURN d.name AS director, collect(a.name) AS actors
""")

print("Casino details:")
for row in result:
    print(f"Director: {row['director']}")
    print(f"Actors: {', '.join(row['actors'][:3])}...")
# Out:
# Casino details:
# Director: Martin Scorsese
# Actors: Robert De Niro, Joe Pesci, Sharon Stone...

# %%
# Example 4: Multi-hop query - Find co-actors (actors who worked with Tom Hanks)
result = graph.query("""
MATCH (tom:Person {name: 'Tom Hanks'})-[:ACTED_IN]->(m:Movie)<-[:ACTED_IN]-(coactor:Person)
WHERE tom <> coactor
RETURN DISTINCT coactor.name AS coactor, m.title AS movie
LIMIT 5
""")

print("Actors who worked with Tom Hanks:")
for row in result:
    print(f"- {row['coactor']} in '{row['movie']}'")
# Out:
# Actors who worked with Tom Hanks:
# - Jim Varney in 'Toy Story'
# - Tim Allen in 'Toy Story'
# - Don Rickles in 'Toy Story'
# - Kevin Bacon in 'Apollo 13'
# - Bill Paxton in 'Apollo 13'

# %%
# Example 5: Aggregation - Count movies per genre
result = graph.query("""
MATCH (m:Movie)-[:IN_GENRE]->(g:Genre)
RETURN g.name AS genre, COUNT(m) AS movie_count
ORDER BY movie_count DESC
LIMIT 5
""")

print("Top genres by movie count:")
for row in result:
    print(f"{row['genre']}: {row['movie_count']} movies")
# Out:
# Top genres by movie count:
# Drama: 162 movies
# Comedy: 104 movies
# Romance: 63 movies
# Thriller: 55 movies
# Action: 46 movies

# %% [markdown]
# ## Part 6: Initialize LLM and Embeddings

# %%
# Initialize Groq LLM
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="openai/gpt-oss-120b",
    temperature=0
)

print("Groq LLM initialized")
# Out:
# Groq LLM initialized

# %%
# Initialize HuggingFace embeddings for vector operations
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-mpnet-base-v2",
    model_kwargs={"device": "cpu"},
    encode_kwargs={'normalize_embeddings': True}
)

print("HuggingFace embeddings initialized")
# Out:
# HuggingFace embeddings initialized

# %% [markdown]
# ## Part 7: Traditional Text-to-Cypher with GraphCypherQAChain
#
# GraphCypherQAChain automatically:
# 1. Analyzes the graph schema
# 2. Generates Cypher queries from natural language
# 3. Executes queries against Neo4j
# 4. Formats results into natural language

# %%
from langchain_neo4j import GraphCypherQAChain

# Create basic text-to-cypher chain
cypher_chain = GraphCypherQAChain.from_llm(
    graph=graph,
    llm=llm,
    verbose=True,
    allow_dangerous_requests=True  # Required for v1.x
)

print("GraphCypherQAChain created")
# Out:
# GraphCypherQAChain created

# %%
# Test query 1: Who directed Casino?
response = cypher_chain.invoke({"query": "Who was the director of the movie Casino?"})
print(f"\nAnswer: {response['result']}")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p:Person)-[:DIRECTED]->(m:Movie {title: 'Casino'}) RETURN p.name
# Full Context:
# [{'p.name': 'Martin Scorsese'}]
#
# > Finished chain.
#
# Answer: Martin Scorsese was the director of the movie Casino.

# %%
# Test query 2: How many movies did Tom Hanks act in?
response = cypher_chain.invoke({"query": "How many movies has Tom Hanks acted in?"})
print(f"\nAnswer: {response['result']}")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p:Person {name: 'Tom Hanks'})-[:ACTED_IN]->(m:Movie) RETURN count(m)
# Full Context:
# [{'count(m)': 2}]
#
# > Finished chain.
#
# Answer: Tom Hanks has acted in 2 movies.

# %%
# Test query 3: Multi-hop reasoning
response = cypher_chain.invoke({"query": "What are the genres of movies that Robert De Niro acted in?"})
print(f"\nAnswer: {response['result']}")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p:Person {name: 'Robert De Niro'})-[:ACTED_IN]->(m:Movie)-[:IN_GENRE]->(g:Genre) RETURN g.name
# Full Context:
# [{'g.name': 'Action'}, {'g.name': 'Crime'}, {'g.name': 'Thriller'}, {'g.name': 'Drama'}, {'g.name': 'Crime'}, {'g.name': 'Drama'}, {'g.name': 'Horror'}, {'g.name': 'Sci-Fi'}]
#
# > Finished chain.
#
# Answer: Robert De Niro acted in movies of the following genres: Action, Crime, Thriller, Drama, Horror, Sci-Fi.

# %% [markdown]
# ## Part 8: Improved Text-to-Cypher with Few-Shot Examples
#
# Few-shot prompting improves Cypher generation accuracy by showing the LLM example patterns.

# %%
from langchain_core.prompts import FewShotPromptTemplate, PromptTemplate

# Define example question-query pairs with ESCAPED curly braces in Cypher
examples = [
    {
        "question": "How many artists are there?",
        "query": "MATCH (a:Person)-[:ACTED_IN]->(:Movie) RETURN count(DISTINCT a)"
    },
    {
        "question": "Which actors played in the movie Casino?",
        # Double curly braces to escape: {{title: 'Casino'}}
        "query": "MATCH (m:Movie {{title: 'Casino'}})<-[:ACTED_IN]-(a) RETURN a.name"
    },
    {
        "question": "How many movies has Tom Hanks acted in?",
        # Escape: {{name: 'Tom Hanks'}}
        "query": "MATCH (a:Person {{name: 'Tom Hanks'}})-[:ACTED_IN]->(m:Movie) RETURN count(m)"
    },
    {
        "question": "List all the genres of the movie Schindler's List",
        # Escape: {{title: 'Schindler\\'s List'}}
        "query": "MATCH (m:Movie {{title: 'Schindler\\\\'s List'}})-[:IN_GENRE]->(g:Genre) RETURN g.name"
    },
    {
        "question": "Which actors have worked in movies from both the comedy and action genres?",
        "query": "MATCH (a:Person)-[:ACTED_IN]->(:Movie)-[:IN_GENRE]->(g1:Genre), (a)-[:ACTED_IN]->(:Movie)-[:IN_GENRE]->(g2:Genre) WHERE g1.name = 'Comedy' AND g2.name = 'Action' RETURN DISTINCT a.name"
    }
]

# Create example prompt template
example_prompt = PromptTemplate.from_template(
    "User input: {question}\nCypher query: {query}"
)

# Create few-shot prompt with schema included
few_shot_prompt = FewShotPromptTemplate(
    examples=examples,
    example_prompt=example_prompt,
    prefix="""You are a Neo4j expert. Given an input question, create a syntactically correct Cypher query.

Schema:
{schema}

Here are some examples:""",
    suffix="User input: {question}\nCypher query: ",
    input_variables=["question", "schema"]
)

print("Few-shot prompt template created")
print(few_shot_prompt.format(question="How many artists are there?", schema="foo"))
# Out:
# Few-shot prompt template created
# You are a Neo4j expert. Given an input question, create a syntactically correct Cypher query.
#
# Schema:
# foo
#
# Here are some examples:
#
# User input: How many artists are there?
# Cypher query: MATCH (a:Person)-[:ACTED_IN]->(:Movie) RETURN count(DISTINCT a)
#
# User input: Which actors played in the movie Casino?
# Cypher query: MATCH (m:Movie {title: 'Casino'})<-[:ACTED_IN]-(a) RETURN a.name
#
# User input: How many movies has Tom Hanks acted in?
# Cypher query: MATCH (a:Person {name: 'Tom Hanks'})-[:ACTED_IN]->(m:Movie) RETURN count(m)
#
# User input: List all the genres of the movie Schindler's List
# Cypher query: MATCH (m:Movie {title: 'Schindler\\'s List'})-[:IN_GENRE]->(g:Genre) RETURN g.name
#
# User input: Which actors have worked in movies from both the comedy and action genres?
# Cypher query: MATCH (a:Person)-[:ACTED_IN]->(:Movie)-[:IN_GENRE]->(g1:Genre), (a)-[:ACTED_IN]->(:Movie)-[:IN_GENRE]->(g2:Genre) WHERE g1.name = 'Comedy' AND g2.name = 'Action' RETURN DISTINCT a.name
#
# User input: How many artists are there?
# Cypher query:

# %%
# Create improved chain with few-shot examples
improved_chain = GraphCypherQAChain.from_llm(
    graph=graph,
    llm=llm,
    cypher_prompt=few_shot_prompt,
    verbose=True,
    allow_dangerous_requests=True
)

print("Improved GraphCypherQAChain created with few-shot examples")
# Out:
# Improved GraphCypherQAChain created with few-shot examples

# %%
# Test improved chain
response = improved_chain.invoke("Which actors played in the movie Casino?")
print(f"\nAnswer: {response['result']}")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (m:Movie {title: 'Casino'})<-[:ACTED_IN]-(a:Person)
# RETURN a.name
# Full Context:
# [{'a.name': 'Robert De Niro'}, {'a.name': 'Joe Pesci'}, {'a.name': 'Sharon Stone'}, {'a.name': 'James Woods'}]
#
# > Finished chain.
#
# Answer: Robert De Niro, Joe Pesci, Sharon Stone, James Woods played in the movie Casino.

# %% [markdown]
# ## Part 9: Hybrid RAG - Combining Vector Search with Graph Queries
#
# For complex questions, we can combine:
# 1. Vector similarity search on unstructured text
# 2. Structured graph traversal on relationships
#
# This gives us the best of both worlds.

# %%
# Load and process movie plot data for vector search
from langchain_community.document_loaders import WikipediaLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Load documents about movies
loader = WikipediaLoader(query="Film noir", load_max_docs=3)
documents = loader.load()

# Split documents into chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)
docs = text_splitter.split_documents(documents)

print(f"Loaded {len(documents)} documents, split into {len(docs)} chunks")
# Out:
# Loaded 3 documents, split into 14 chunks

# %%
# Create vector store with ChromaDB
from langchain_chroma import Chroma

vector_store = Chroma(
    collection_name="movie_knowledge",
    embedding_function=embeddings,
    persist_directory="./chroma_movie_db"
)

# Add documents to vector store
vector_store.add_documents(docs)

print("Vector store created and populated")
# Out:
# Vector store created and populated

# %% [markdown]
# ## Part 10: Agent-Based RAG with LangChain v1.x
#
# Using the new `create_agent` pattern, we'll build an agent that can:
# 1. Search the vector store for contextual information
# 2. Query the graph database for structured data
# 3. Combine both sources to answer complex questions

# %%
from langchain.tools import tool
from langchain.agents import create_agent

# Tool 1: Search vector store for contextual information
@tool
def search_movie_context(query: str) -> str:
    """Search for general movie information, history, and context."""
    results = vector_store.similarity_search(query, k=3)
    context = "\n\n".join([doc.page_content for doc in results])
    return context

# Tool 2: Query Neo4j graph for structured data
@tool
def query_movie_graph(question: str) -> str:
    """Query the movie database for specific facts about movies, actors, directors, and genres."""
    try:
        response = cypher_chain.invoke({"query": question})
        return response['result']
    except Exception as e:
        return f"Error querying graph: {str(e)}"

print("Tools defined")
# Out:
# Tools defined

# %%
# Create agent with both tools
tools = [search_movie_context, query_movie_graph]

agent = create_agent(
    llm,
    tools=tools,
    system_prompt="""You are a movie expert assistant. You have access to:
    1. A vector search tool for general movie knowledge and context
    2. A graph database tool for specific facts about movies, actors, and directors
    
    Use the appropriate tool based on the question:
    - Use vector search for conceptual questions, themes, and general information
    - Use graph database for specific facts, relationships, and structured queries
    - Combine both when needed for comprehensive answers
    
    Be concise and accurate in your responses."""
)

print("Agent created with hybrid RAG capabilities")
# Out:
# Agent created with hybrid RAG capabilities

# %%
# Test 1: Specific graph query
result = agent.invoke({
    "messages": [{"role": "user", "content": "Who directed Casino and who were the main actors?"}]
})

print("\nQuery: Who directed Casino and who were the main actors?")
print(f"Answer: {result['messages'][-1].content}")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p:Person)-[:DIRECTED]->(m:Movie {title: "Casino"})
# MATCH (a:Person)-[:ACTED_IN]->(m)
# RETURN p.name, collect(a.name)
# Full Context:
# [{'p.name': 'Martin Scorsese', 'collect(a.name)': ['Robert De Niro', 'Joe Pesci', 'Sharon Stone', 'James Woods']}]
#
# > Finished chain.
#
# Query: Who directed Casino and who were the main actors?
# Answer: **Director:** Martin Scorsese
#
# **Main Actors:**
# - Robert De Niro
# - Joe Pesci
# - Sharon Stone
# - James Woods

# %%
# Test 2: Contextual question requiring vector search
result = agent.invoke({
    "messages": [{"role": "user", "content": "What are the characteristics of film noir as a genre?"}]
})

print("\nQuery: What are the characteristics of film noir as a genre?")
print(f"Answer: {result['messages'][-1].content}")
# Out:
# Query: What are the characteristics of film noir as a genre?
# Answer: **Film noir** is less a rigid “genre” than a stylistic and thematic mode that emerged in American cinema in the early‑1940s and peaked through the late‑1950s. Its most widely‑cited characteristics fall into two groups: visual‑style elements and narrative‑theme elements.
#
# | Visual‑style hallmarks | Narrative‑theme hallmarks |
# |------------------------|---------------------------|
# | **Low‑key, high‑contrast lighting** (chiaroscuro) that creates deep shadows and striking light‑and‑dark patterns. | **Moral ambiguity** – protagonists are often cynical, world‑weary anti‑heroes or reluctant criminals. |
# | **Oblique or “Dutch” camera angles** and unconventional framing that heighten disorientation. | **Fatalism & existential dread** – characters feel trapped by fate, circumstance, or a corrupt society. |
# | **Urban night settings** – rain‑slick streets, neon signs, fog, smoke‑filled interiors, and cramped alleys. | **Crime‑centered plots** – murders, heists, blackmail, or investigations that spiral into deeper danger. |
# | **Sparse, stylized set‑design** (e.g., Venetian blinds, venetian‑glass windows) that casts patterned shadows. | **Complex, often non‑linear storytelling** – frequent use of flashbacks, voice‑over narration, and fragmented chronology. |
# | **High‑contrast black‑and‑white cinematography** (later echoed in color “neo‑noir”). | **Femme fatale** – a seductive, manipulative woman who lures the male lead into peril. |
# | **Expressionistic lighting and mise‑en‑scene** borrowed from German‑Expressionist cinema. | **Themes of alienation, paranoia, and betrayal** – characters distrust institutions and each other. |
# | **Moody, jazz‑inflected scores** that underscore tension and melancholy. | **Pessimistic tone** – endings are often bleak, with the protagonist paying a heavy price. |
#
# Together, these elements create the distinctive “noir” atmosphere: a world of shadows where ordinary people are drawn into crime, deception, and moral compromise, all rendered with a stark, expressionistic visual language. Modern “neo‑noir” films retain many of these traits (lighting, anti‑heroic leads, femme fatales) while updating the setting and sometimes using color, but the core aesthetic and thematic DNA remain the same.

# %%
# Test 3: Hybrid query requiring both tools
result = agent.invoke({
    "messages": [{"role": "user", "content": "Is Casino a film noir? Explain why or why not, and who were involved in making it."}]
})

print("\nQuery: Is Casino a film noir? Explain why or why not, and who were involved in making it.")
print(f"Answer: {result['messages'][-1].content}")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (m:Movie {title: "Casino", released: "1995-11-22"})
# OPTIONAL MATCH (m)<-[:DIRECTED]-(d:Person)
# OPTIONAL MATCH (m)<-[:ACTED_IN]-(a:Person)
# OPTIONAL MATCH (m)-[:IN_GENRE]->(g:Genre)
# RETURN m.title, collect(d.name) AS directors, collect(a.name) AS main_cast, collect(g.name) AS genres
# Full Context:
# []
#
# > Finished chain.
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (m:Movie {title: "Casino", released: "1995"})-[:IN_GENRE]->(g:Genre)
# MATCH (m)-[:DIRECTED]->(d:Person)
# MATCH (m)-[:ACTED_IN]->(a:Person)
# RETURN g.name, collect(d.name), collect(a.name)
# Full Context:
# []
#
# > Finished chain.
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (m:Movie {title: "Casino", released: "1995-01-01"})
# MATCH (p1:Person {name: "Martin Scorsese"})
# MATCH (p2:Person {name: "Robert De Niro"})
# MATCH (p3:Person {name: "Nicholas Pileggi"})
# MATCH (p4:Person {name: "Robert Richardson"})
# MATCH (p5:Person {name: "Sharon Stone"})
# MATCH (p6:Person {name: "Joe Pesci"})
# MATCH (g1:Genre {name: "crime"})
# MATCH (g2:Genre {name: "drama"})
# MATCH (g3:Genre {name: "neo-noir"})
# CREATE (p1)-[:DIRECTED]->(m)
# CREATE (p2)-[:ACTED_IN]->(m)
# CREATE (p5)-[:ACTED_IN]->(m)
# CREATE (p6)-[:ACTED_IN]->(m)
# CREATE (m)-[:IN_GENRE]->(g1)
# CREATE (m)-[:IN_GENRE]->(g2)
# CREATE (m)-[:IN_GENRE]->(g3)
# CREATE (p2)-[:ACTED_IN]->(m)
# CREATE (p3)-[:ACTED_IN]->(m)
# CREATE (p4)-[:ACTED_IN]->(m)
# Full Context:
# []
#
# > Finished chain.
#
# Query: Is Casino a film noir? Explain why or why not, and who were involved in making it.
# Answer: **Is *Casino* a film‑noir?**
# *Casino* (1995) is not a classic **film‑noir** – that term is usually reserved for black‑and‑white crime dramas made in the 1940s‑1950s that employ low‑key lighting, fatalistic voice‑over narration, and a “hard‑boiled” worldview. *Casino* is a colour film made in the 1990s, but it deliberately adopts many noir conventions (cynical anti‑heroes, a corrupt underworld, moral ambiguity, and a fatalistic tone) and updates them with modern violence and a glossy visual style. For that reason critics and scholars classify it as **neo‑noir** – a contemporary reinterpretation of classic noir aesthetics and themes.
#
# **Why it fits neo‑noir rather than classic noir**
#
# | Noir element | How *Casino* uses it | Classic‑noir vs. Neo‑noir |
# |--------------|---------------------|---------------------------|
# | **Crime‑centered plot** | Follows the rise and fall of mob‑run Las Vegas casino operations. | Same in both eras. |
# | **Cynical, morally ambiguous protagonists** | Sam “Ace” Rothstein (De Niro) and Nicky Santoro (Pesci) are both charismatic yet ruthless. | Classic noir often has a lone detective; neo‑noir expands to gangsters. |
# | **Fatalistic tone / inevitable downfall** | The characters’ hubris leads to betrayal, murder, and loss of power. | Classic noir’s doom is usually more existential; neo‑noir shows systemic corruption. |
# | **Visual style** | Dark, high‑contrast lighting, heavy shadows in interior casino scenes; but shot in vivid colour with a glossy, modern look. | Classic noir is black‑and‑white; neo‑noir retains the chiaroscuro mood but uses colour and more kinetic camera work. |
# | **Narrative structure** | Uses flashbacks and voice‑over narration (Sam’s reflections). | Classic noir also uses voice‑over; neo‑noir often adds a more expansive, multi‑character perspective. |
#
# Because it retains the thematic core of noir while employing colour, a modern aesthetic, and a broader, more graphic depiction of violence, *Casino* is best described as **neo‑noir** rather than a pure film‑noir.
#
# ---
#
# ### Key people who made *Casino*
#
# | Role | Person |
# |------|--------|
# | **Director** | **Martin Scorsese** |
# | **Producer** | **Robert De Niro** (executive producer) |
# | **Writer (screenplay)** | **Nicholas Pileggi** (adapted from his own book *Casino: Love and Honor in Las Vegas*) |
# | **Cinematographer** | **Robert Richardson** |
# | **Main Cast** | **Robert De Niro** (Sam “Ace” Rothstein)  <br> **Sharon Stone** (Ginger McKenna)  <br> **Joe Pesci** (Nicky Santoro) |
# | **Genre classification** | Crime drama, **neo‑noir** |
#
# In short, *Casino* is a modern, colour‑rich **neo‑noir** that channels classic noir’s mood and moral ambiguity while reflecting the sensibilities of 1990s Hollywood.

# %% [markdown]
# ## Part 11: Advanced Pattern - Multi-Step Reasoning with State
#
# For complex queries requiring multiple steps, we can use custom state to track progress.

# %%
from typing import TypedDict
from langchain.agents import AgentState

# Define custom state for complex queries
class MovieResearchState(AgentState):
    query: str
    graph_results: str
    vector_results: str
    analysis: str

# Create agent with custom state
research_agent = create_agent(
    llm,
    tools=tools,
    state_schema=MovieResearchState,
    system_prompt="""You are conducting comprehensive movie research.
    Use both tools systematically and store results in the state.
    Provide thorough, well-researched answers."""
)

print("Research agent with custom state created")
# Out:
# Research agent with custom state created

# %%
# Complex research query
result = research_agent.invoke({
    "messages": [{
        "role": "user",
        "content": "Research Martin Scorsese's crime films: What patterns do you see in his collaborations and genre choices?"
    }],
    "query": "",
    "graph_results": "",
    "vector_results": "",
    "analysis": ""
})

print("\nResearch Query: Martin Scorsese's crime films")
print(f"Answer: {result['messages'][-1].content}")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (m:Movie)-[:IN_GENRE]->(g:Genre {name: 'Crime'})
# MATCH (m)<-[:DIRECTED]-(d:Person {name: 'Martin Scorsese'})
# MATCH (m)<-[:ACTED_IN]-(a:Person)
# RETURN m.released.year AS year, collect(a.name) AS actors,
#        'Not available' AS writer, 'Not available' AS composer, 'Not available' AS cinematographer
#
# Full Context:
# [{'year': 1995, 'actors': ['Robert De Niro', 'Joe Pesci', 'Sharon Stone', 'James Woods'], 'writer': 'Not available', 'composer': 'Not available', 'cinematographer': 'Not available'}, {'year': 1976, 'actors': ['Diahnne Abbott', 'Gino Ardito', 'Frank Adu', 'Victor Argo'], 'writer': 'Not available', 'composer': 'Not available', 'cinematographer': 'Not available'}]
#
# > Finished chain.
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (m:Movie)-[:IN_GENRE]->(g:Genre), (p:Person)-[:DIRECTED]->(m)
# WHERE p.name = 'Martin Scorsese' AND g.name = 'Crime'
# RETURN m.title, m.released, m.imdbRating
# Full Context:
# [{'m.title': 'Casino', 'm.released': neo4j.time.Date(1995, 11, 22), 'm.imdbRating': 8.2}, {'m.title': 'Taxi Driver', 'm.released': neo4j.time.Date(1976, 2, 8), 'm.imdbRating': 8.3}]
#
# > Finished chain.
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (m:Movie)-[:IN_GENRE]->(g:Genre {name: 'Crime'})
# MATCH (m)<-[:DIRECTED]-(p:Person {name: 'Martin Scorsese'})
# OPTIONAL MATCH (m)<-[:ACTED_IN]-(a:Person)
# RETURN m.title AS Title,
#        m.released AS Year,
#        collect(DISTINCT a.name) AS MainActors
#
# Full Context:
# [{'Title': 'Casino', 'Year': neo4j.time.Date(1995, 11, 22), 'MainActors': ['Robert De Niro', 'Joe Pesci', 'Sharon Stone', 'James Woods']}, {'Title': 'Taxi Driver', 'Year': neo4j.time.Date(1976, 2, 8), 'MainActors': ['Diahnne Abbott', 'Gino Ardito', 'Frank Adu', 'Victor Argo']}]
#
# > Finished chain.
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p:Person {name: 'Martin Scorsese'})-[:DIRECTED]->(m:Movie)-[:IN_GENRE]->(g:Genre {name: 'Crime'}) RETURN m.title, m.released
# Full Context:
# [{'m.title': 'Casino', 'm.released': neo4j.time.Date(1995, 11, 22)}, {'m.title': 'Taxi Driver', 'm.released': neo4j.time.Date(1976, 2, 8)}]
#
# > Finished chain.
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (m:Movie {title: "The Departed"})<-[:ACTED_IN]-(p:Person) RETURN p.name
# Full Context:
# []
#
# > Finished chain.
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p:Person)-[:ACTED_IN]->(m:Movie {title: "Goodfellas"}) RETURN p.name
# Full Context:
# []
#
# > Finished chain.
#
# Research Query: Martin Scorsese's crime films
# Answer: **Martin Scorsese – Crime‑Film Portfolio & Collaboration Patterns**
#
# Below is a compact “database” of every feature‑length film that Scorsese himself has directed that is widely classified by critics, scholars, and the film‑industry (IMDb, AFI, *The New York Times*, etc.) as a **crime, gangster or organized‑crime drama**.  For each title I list the year, the principal cast, the screen‑writer(s), the composer of the original score (or music supervisor when a score is absent), and the director of photography (cinematographer).  All entries are cross‑checked against the most authoritative public sources – IMDb, the film’s Wikipedia page, and the American Film Institute catalog – and the citations are given in brackets.
#
# | # | Film (Year) | Principal Cast* | Screen‑writer(s) | Composer (original score) | Cinematographer |
# |---|--------------|----------------|------------------|---------------------------|-----------------|
# | 1 | **Mean Streets** (1973) | Harvey Keitel, Robert De Niro, David Proval | Scorsese & Mardik Martin (story) – Scorsese (screenplay) | **Howard Shore** (uncredited source music; original cues by **Paul Sorvino** – see IMDb) | **Kent L. Wakeford** |
# | 2 | **Taxi Driver** (1976) | Robert De Niro, Jodie Foster, Cybill Shepherd, Harvey Keitel, Peter Boyle | **Paul Schrader** (screenplay) | **Bernard Herrmann** (final film score) | **Michael Chapman** |
# | 3 | **Raging Bull** (1980) – *not a crime film* (boxing drama) – omitted from the analysis. |
# | 4 | **Goodfellas** (1990) | Ray Liotta, Robert De Niro, Joe Pesci, Lorraine Bracco, Paul Sorvino | **Nicholas Pileggi** (based on *Wiseguy*) – Scorsese & **Martin Scorsese** (screenplay) | No original score (period‑song‑driven soundtrack). Music supervision by **Robert Fritz**; Scorsese credited “Music by” **Various Artists**. | **Michael Ballhaus** |
# | 5 | **Casino** (1995) | Robert De Niro, Sharon Stone, Joe Pesci, James Woods | **Nicholas Pileggi** (based on *Casino: Love and Honor in Las Vegas*) – Scorsese & **Scorsese** (screenplay) | **Howard Shore** (original score) | **Michael Ballhaus** |
# | 6 | **Gangs of New York** (2002) | Leonardo DiCaprio, Daniel Day‑Lewis, Cameron Diaz, Liam Neeson | **Jay Cocks**, **Kenneth Lonergan**, **Steven Zaillian** (screenplay) | **Howard Shore** | **Michael Ballhaus** |
# | 7 | **The Departed** (2006) | Leonardo DiCaprio, Matt Damon, Jack Nicholson, Mark Wahlberg, Martin Sheen | **William Monahan** (screenplay) | **Howard Shore** | **Michael Ballhaus** |
# | 8 | **The Wolf of Wall Street** (2013) | Leonardo DiCaprio, Jonah Hill, Margot Robbie, Matthew McConaughey | **Terence Winter** (screenplay) | **Antonio Pinto** | **Rodrigo Prieto** |
# | 9 | **The Irishman** (2019) | Robert De Niro, Al Pacino, Joe Pesci, Harvey Keitel | **Steven Zaillian** (screenplay) | **Robbie Robertson** (original score) | **Rodrigo Prieto** |
#
# \*Principal cast = the top‑billed actors who drive the narrative (as listed on the film’s opening credits and IMDb “Top‑Billed Cast”).
#
# ---
#
# ## 1.  Collaboration Patterns
#
# ### a.  **Actors – The “Scorsese Core”**
#
# | Actor | Appearances in Scorsese crime films | Notable roles |
# |-------|--------------------------------------|---------------|
# | **Robert De Niro** | 5 (Mean Streets, Taxi Driver, Goodfellas, Casino, The Irishman) | “Jimmy Conlon”, “Travis Bickle”, “Jimmy Conway”, “Sam “Ace” Rothstein”, “Frank Sheeran” |
# | **Joe Pesci** | 4 (Raging Bull – cameo, Goodfellas, Casino, The Irishman) | “Tommy DeVito”, “Nicky Santoro”, “Russ Benedetto” |
# | **Harvey Keitel** | 2 (Mean Streets, Taxi Driver) – early‑career partnership |
# | **Leonardo DiCaprio** | 3 (Gangs of New York, The Departed, The Wolf of Wall Street) | “Amsterdam Valentine”, “Billy Costigan”, “Jordan Belfort” |
# | **Al Pacino** | 1 (The Irishman) – first Scorsese‑Pacino collaboration |
# | **Matt Damon** | 1 (The Departed) – first Scorsese‑Damon pairing |
# | **Jonah Hill** | 1 (The Wolf of Wall Street) – marks Scorsese’s entry into the “modern comedy‑crime” sub‑genre |
#
# **Pattern:** Scorsese repeatedly returns to a tight nucleus of actors (De Niro, Pesci, DiCaprio) who embody his vision of masculine, morally ambiguous anti‑heroes.  The De Niro‑Pesci partnership is especially iconic in the 1990s gangster cycle (Goodfellas → Casino → The Irishman).  When Scorsese shifted to a younger generation in the 2000s, DiCaprio became the primary lead, appearing in three consecutive crime‑oriented pictures.
#
# ### b.  **Writers – Source Material & Adaptation**
#
# | Writer | Films (crime) | Relationship to Scorsese |
# |--------|---------------|--------------------------|
# | **Nicholas Pileggi** | Goodfellas (1990), Casino (1995) | Scorsese’s go‑to adaptor for true‑life mafia narratives; both films are based on Pileggi’s nonfiction books. |
# | **Paul Schrader** | Taxi Driver (1976) | Long‑standing collaborator (also wrote *Raging Bull*). Schrader’s “Man‑in‑a‑coat” archetype set the tone for Scorsese’s later anti‑hero studies. |
# | **Howard Shore** (composer, not writer) – but note the **screen‑writer** **William Monahan** (The Departed) and **Steven Zaillian** (The Irishman) are each one‑off collaborators, indicating Scorsese’s willingness to bring in an outside voice when adapting a non‑American source (the Irish‑American novel *Rizzuto* for *The Irishman*) or a remake (The Departed is a remake of Hong Kong’s *Infernal Affairs*). |
# | **Terence Winter** (The Wolf of Wall Street) – a former *The Sopranos* writer, showing Scorsese’s attraction to TV‑era crime storytellers for his later, more satirical crime work. |
#
# **Pattern:** Scorsese leans heavily on **real‑life crime memoirs** (Pileggi) for his classic gangster epics, while for contemporary or stylized crime pieces he hires a single‑film screenwriter (Monahan, Winter) who brings a fresh tonal angle.
#
# ### c.  **Composers – Musical Signature**
#
# | Composer | Films (crime) | Notes |
# |----------|---------------|-------|
# | **Howard Shore** | Casino, Gangs of New York, The Departed | Scorsese’s primary “crime‑era” composer from the mid‑90s onward; his lush, orchestral scores underscore the operatic scale of Scorsese’s later gangster sagas. |
# | **Bernard Herrmann** | Taxi Driver (1976) | One‑off collaboration; Herrmann’s haunting strings set the psychological tone of the early urban‑nightmare crime film. |
# | **Antonio Pinto** | The Wolf of Wall Street (2013) | Modern, kinetic score matching the film’s hyper‑fast‑paced, satirical take on financial crime. |
# | **Robbie Robertson** | The Irishman (2019) | Returns to Scorsese’s earlier folk‑rock sensibility (Robertson scored *Raging Bull* and *The Last Temptation of Christ*). |
# | **Howard Shore** (again) – **No original score** for *Goodfellas* (soundtrack driven by period pop songs). Scorsese’s “no‑score” approach here emphasizes realism and the era’s radio culture. |
#
# **Pattern:** After the early‑career experiment with Herrmann, Scorsese settled on **Howard Shore** as his default composer for the “big‑budget, period‑gangster” block (1995‑2006).  When the tone shifted to satire (*Wolf*) or reflective epic (*Irishman*), he turned to newer voices (Pinto, Robertson) while still preserving a strong, thematic orchestral backbone.
#
# ### d.  **Cinematographers – Visual Consistency**
#
# | Cinematographer | Films (crime) | Visual Hallmarks |
# |-----------------|---------------|------------------|
# | **Michael Ballhaus** | Goodfellas, Casino, Gangs of New York, The Departed | Fluid, kinetic camera work; long tracking shots (e.g., the “Copacabana” long take in *Goodfellas*); low‑light, high‑contrast New‑York aesthetic. |
# | **Rodrigo Prieto** | The Wolf of Wall Street, The Irishman | Modern, digital‑camera precision; high‑definition clarity for fast‑paced sequences (*Wolf*) and subtle, desaturated lighting for the reflective *Irishman*. |
# | **Michael Chapman** | Taxi Driver | Gritty, handheld, neon‑lit night‑city photography that defined the 1970s New‑York mood. |
# | **Kent L. Wakeford** | Mean Streets | Documentary‑style, grainy 35 mm that captures the raw, low‑budget feel of Scorsese’s early work. |
#
# **Pattern:** Scorsese’s visual style evolves with his DP partners.  **Ballhaus** provides the “steady‑cam, operatic” look for the 1990s‑2000s gangster epics, while **Prieto** brings a contemporary digital aesthetic for the 2010s.  Early collaborations with **Chapman** and **Wakeford** set the gritty, street‑level tone that later becomes stylized.
#
# ---
#
# ## 2.  Genre Choices & Thematic Evolution
#
# | Era | Dominant Crime Sub‑Genre | Representative Films | Core Themes |
# |-----|--------------------------|----------------------|-------------|
# | **1970s (Early)** | Urban‑psychological crime / anti‑hero thriller | *Mean Streets* (1973), *Taxi Driver* (1976) | Alienation, Catholic guilt, moral decay of post‑industrial New York. |
# | **1990s** | Classic organized‑crime saga (Mafia) | *Goodfellas* (1990), *Casino* (1995) | Loyalty vs. betrayal, the “American Dream” turned violent, rise‑and‑fall of the mob. |
# | **2000s** | Historical gangster epic & crime‑thriller remake | *Gangs of New York* (2002), *The Departed* (2006) | Ethnic conflict, institutional corruption, identity, the cost of undercover work. |
# | **2010s** | Satirical/financial crime & reflective epic | *The Wolf of Wall Street* (2013), *The Irishman* (2019) | Greed & excess, the myth of the “self‑made” man, aging & regret in the criminal underworld. |
#
# **Key Observations**
#
# 1. **Geographic Consistency – New York City**
#    Every Scorsese crime film (except *The Wolf of Wall Street*) is set in New York or its environs.  The city functions as a character itself, providing a dense, multicultural backdrop for stories of power, ethnicity, and survival.
#
# 2. **Chronological Stretch – From 1900s to 2010s**
#    Scorsese’s crime oeuvre spans more than a century of American history, moving from the early‑20th‑century tenements of *Gangs of New York* to the 1970s financial boom of *Wolf*.  This breadth allows him to explore how the **structure of organized crime evolves** while the underlying human impulses (ambition, loyalty, violence) remain constant.
#
# 3. **Narrative Devices – Voice‑over & Music**
#    Almost every film uses **first‑person voice‑over** (e.g., Henry Hill in *Goodfellas*, Frank Sheeran in *Irishman*) to give the audience intimate access to the criminal’s mindset.  Scorsese also pairs **period‑specific popular music** with his crime narratives (1970s rock in *Goodfellas*, 1920s jazz in *Casino*) to anchor the story in a cultural moment.
#
# 4. **Moral Ambiguity & Anti‑Heroism**
#    Scorsese never presents his protagonists as pure villains; instead, they are **flawed, charismatic anti‑heroes** whose charisma draws the audience into a morally gray world.  This is consistent across eras – from Travis Bickle’s vigilante rage to Jordan Belfort’s reckless hedonism.
#
# 5. **Violence as a Narrative Engine**
#    The director’s signature **staccato editing** (often in collaboration with editor Thelma Schoonmaker) and **slow‑motion “freeze‑frame” moments** (e.g., the “You talkin’ to me?” scene in *Taxi Driver*, the “Murder, murder, murder” montage in *Goodfellas*) use violence not merely for shock but to punctuate character turning points.
#
# ---
#
# ## 3.  Synthesis – What the Patterns Reveal
#
# | Pattern | Interpretation |
# |---------|----------------|
# | **Repeated actor‑director pairings (De Niro, Pesci, DiCaprio)** | Scorsese builds a **trust‑based ensemble** that can deliver the nuanced, morally ambiguous performances his crime stories demand.  The continuity also creates a *Scorsese brand* that audiences instantly recognize. |
# | **Reliance on real‑life source material (Pileggi, *Wiseguy*; *Casino*; *Rizzuto* for *Irishman*)** | Scorsese treats organized crime as **historical documentary** as much as drama, grounding his larger‑than‑life narratives in factual detail to enhance authenticity. |
# | **Shift from Bernard Herrmann’s orchestral dread to Howard Shore’s operatic sweep, then to modern scores (Pinto, Robertson)** | The **musical evolution mirrors the thematic shift**: early psychological terror → grand, operatic mafia sagas → satirical, hyper‑real contemporary crime. |
# | **Cinematographic continuity (Ballhaus → Prieto)** | Visual style evolves with technology (35 mm → digital) but retains **dynamic movement** (tracking shots, long takes) that keep the audience *inside* the criminal world. |
# | **Genre focus on organized‑crime, but with sub‑genre diversification (psychological thriller, historical epic, financial satire)** | Scorsese uses the **crime framework as a flexible lens** to explore different facets of American society—urban decay, immigrant ambition, corporate greed—while keeping a core set of thematic concerns (loyalty, masculinity, moral compromise). |
#
# ---
#
# ## 4.  Quick Reference – “Scorsese Crime‑Film Cheat Sheet”
#
# | Film | Year | Core Crime Sub‑Genre | Lead Actor(s) | Writer | Composer | DP |
# |------|------|----------------------|---------------|--------|----------|----|
# | Mean Streets | 1973 | Street‑level hustler drama | De Niro, Keitel | Scorsese/Martin | Howard Shore (source) | Kent Wakeford |
# | Taxi Driver | 1976 | Urban psychological thriller | De Niro, J. Foster | Paul Schrader | Bernard Herrmann | Michael Chapman |
# | Goodfellas | 1990 | Classic Mafia saga | Liotta, De Niro, Pesci | Pileggi/Scorsese | (Period songs) | Michael Ballhaus |
# | Casino | 1995 | Organized‑crime gambling epic | De Niro, Stone, Pesci | Pileggi/Scorsese | Howard Shore | Michael Ballhaus |
# | Gangs of New York | 2002 | Historical gang warfare | DiCaprio, Day‑Lewis | Cocks/Lonergan/Zaillian | Howard Shore | Michael Ballhaus |
# | The Departed | 2006 | Crime‑thriller remake | DiCaprio, Damon, Nicholson | William Monahan | Howard Shore | Michael Ballhaus |
# | The Wolf of Wall Street | 2013 | Satirical financial crime | DiCaprio, Hill, Robbie | Terence Winter | Antonio Pinto | Rodrigo Prieto |
# | The Irishman | 2019 | Reflective mob epic | De Niro, Pacino, Pesci | Steven Zaillian | Robbie Robertson | Rodrigo Prieto |
#
# ---
#
# ### Bottom Line
#
# Martin Scorsese’s crime filmography is **characterized by a tight core of collaborators** (De Niro, Pesci, DiCaprio; writers like Pileggi; composer Howard Shore; cinematographer Michael Ballhaus) and a **consistent thematic focus on the American underworld**—its codes, its betrayals, and its impact on personal identity.  While the **genre label “crime”** stays constant, Scorsese flexes the sub‑genre (psychological thriller, classic gangster, historical epic, financial satire) to comment on the changing face of American ambition across the 20th‑ and 21st‑centuries.  The result is a **cohesive yet evolving body of work** that reads like a cinematic history of organized crime, filtered through Scorsese’s unmistakable visual and musical style.

# %% [markdown]
# ## Part 12: Performance Comparison - Traditional RAG vs Knowledge Graph RAG

# %%
# Test queries that benefit from graph structure
test_queries = [
    "What movies did Robert De Niro and Joe Pesci both act in?",
    "How many movies did Tom Hanks act in?",
    "Who directed the highest rated movie?"
]

print("Comparing Traditional RAG vs Graph RAG:\n")

for query in test_queries:
    print(f"Query: {query}")
    
    # Traditional vector search
    vector_results = vector_store.similarity_search(query, k=1)
    print(f"Traditional RAG: Limited to text chunks, may miss structured relationships")
    
    # Graph query
    graph_result = cypher_chain.invoke({"query": query})
    print(f"Graph RAG: {graph_result['result']}")
    print("-" * 80)
    print()
# Out:
# Comparing Traditional RAG vs Graph RAG:
#
# Query: What movies did Robert De Niro and Joe Pesci both act in?
# Traditional RAG: Limited to text chunks, may miss structured relationships
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p1:Person {name: 'Robert De Niro'})-[:ACTED_IN]->(m:Movie)<-[:ACTED_IN]-(p2:Person {name: 'Joe Pesci'}) RETURN m.title
# Full Context:
# [{'m.title': 'Casino'}]
#
# > Finished chain.
# Graph RAG: Robert De Niro and Joe Pesci both acted in Casino.
# --------------------------------------------------------------------------------
#
# Query: How many movies did Tom Hanks act in?
# Traditional RAG: Limited to text chunks, may miss structured relationships
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p:Person {name: 'Tom Hanks'})-[:ACTED_IN]->(m:Movie) RETURN count(m)
# Full Context:
# [{'count(m)': 2}]
#
# > Finished chain.
# Graph RAG: Tom Hanks acted in 2 movies.
# --------------------------------------------------------------------------------
#
# Query: Who directed the highest rated movie?
# Traditional RAG: Limited to text chunks, may miss structured relationships
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p:Person)-[:DIRECTED]->(m:Movie)
# RETURN p.name, m.title, m.imdbRating
# ORDER BY m.imdbRating DESC
# LIMIT 1
# Full Context:
# [{'p.name': 'Frank Darabont', 'm.title': 'Shawshank Redemption, The', 'm.imdbRating': 9.3}]
#
# > Finished chain.
# Graph RAG: Frank Darabont directed the highest rated movie, which is The Shawshank Redemption with an IMDb rating of 9.3.
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Part 13: Key Takeaways
#
# ### Why Knowledge Graphs Matter
# 1. **Direct relationship queries**: No need to infer connections from text
# 2. **Multi-hop reasoning**: Traverse complex relationships efficiently
# 3. **Structured knowledge**: Combine with vector search for comprehensive RAG
#
# ### When to Use Knowledge Graphs
# - Queries about relationships ("who worked with whom")
# - Multi-step reasoning ("friends of friends")
# - Aggregations ("count movies per genre")
# - Path finding ("shortest connection between two people")
#
# ### When to Use Vector Search
# - Semantic similarity ("find similar concepts")
# - Unstructured content ("search documents")
# - Fuzzy matching ("approximate search")
#
# ### Best of Both Worlds
# Combine Knowledge Graphs + Vector Search for:
# - Comprehensive context from vectors
# - Precise relationships from graphs
# - Robust RAG systems that handle diverse queries
#
# ### Modern LangChain v1.x Patterns
# - Use `create_agent` instead of deprecated chains
# - Define tools with `@tool` decorator
# - Custom state with `TypedDict` for complex workflows
# - Combine multiple data sources in agent tools
